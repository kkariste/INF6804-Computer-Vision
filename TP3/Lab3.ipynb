# %%
#!pip install ultralytics
import cv2
from ultralytics import YOLO
import os

# %%
currDirectory = os.getcwd()

# %% [markdown]
# #### Tracking sur les données de Moodle

# %%
frames_folder = "data/frames/"           # Folder which contains all the images
frame_files = os.listdir(frames_folder)   # List of image filenames
#frame_files.sort()  # Sort the list of files
frame_files =  sorted(frame_files, key=lambda x: int(x[5:-4]))

# Delete the file if it's already exist
if os.path.exists(currDirectory + '/results.txt'):
    os.remove(currDirectory + '/results.txt')

def detect_track_data():
    
    # Load the YOLOv8 model detection
    model = YOLO('yolov8n.pt')

    for frame_id, frame_file in enumerate(frame_files) :
        frame_path = os.path.join(frames_folder, frame_file)   # image path
        frame = cv2.imread(frame_path, cv2.IMREAD_COLOR)       # Charger et lire l'image
    
        if frame is not None:
            
            frame_id += 1
            
            # Run YOLOv8 tracking on the frame, persisting tracks between frames, selecting tracker and objet of interest = 41 = cup
            # Set show = True to see tracking results directly
            results = model.track(frame, imgsz=640, persist=True, tracker="bytetrack.yaml", classes=41, verbose=False, show=False, conf=0.25, iou=0.7)
            
            # Get the boxes and track IDs because in zip some id isn't present
            if results[0].boxes.id is not None:
                boxes = results[0].boxes.xyxy.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
            
            
            for box, track_id in zip(boxes, track_ids):
                x_min = int(box[0])
                y_min = int(box[1])
                x_max = int(box[2])
                y_max = int(box[3])
                width = x_max - x_min
                height = y_max - y_min
                # Save the results in results.txt
                with open(currDirectory + '/results.txt', 'a+') as file:
                    file.write(f"{frame_id} {track_id} {x_min} {y_min} {width} {height}\n")
            
        else:
            print(f"frame not found or impossible to read")

detect_track_data()

# %% [markdown]
# #### Tracking sur les jeux de données MOT17

# %%
# Open MOT17 video train image
mot17_folder = "MOT17/train"
directories = [d for d in os.listdir(mot17_folder)]


for dir in directories:
    
    
    
    images_path = f"{mot17_folder}/{dir}/img1"
    output_file = f"/TrackEval/data/trackers/mot_challenge/MOT17-train/ByteTrack/data/{dir}.txt"

    image_files = [f for f in os.listdir(images_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

    # Sort the files by their digits, take off the word "frame" and the extension
    image_files.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
    
    # Load the YOLOv8 model detection
    model = YOLO('yolov8n.pt')
    
    # Dictionnaire pour stocker les informations de détection
    detections_dict = {}  
    
    # Delate the output file if already exist
    if os.path.exists(currDirectory + output_file):
        os.remove(currDirectory + output_file)
    
    for image_id, image in enumerate(image_files):

        image = cv2.imread(os.path.join(images_path, image_files[image_id]))
        image_id += 1

        # Run YOLOv8 tracking on the frame, persisting tracks between frames, and select class pedestrian
        results = model.track(image, imgsz=640, data='coco128.yaml', persist=True, tracker="bytetrack.yaml", classes=[0], verbose=False, show=False, conf=0.25, iou=0.7)

        # Get the boxes and track IDs
        if results[0].boxes.id is not None and hasattr(results[0].boxes, 'id'):
            boxes = results[0].boxes.xyxy.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()

            # Ajouter les détections au dictionnaire detections_dict
            for box, track_id in zip(boxes, track_ids):
                x_min = box[0]
                y_min = box[1]
                x_max = box[2]
                y_max = box[3]
                width = x_max - x_min
                height = y_max - y_min

                if track_id not in detections_dict:
                    detections_dict[track_id] = []
                detections_dict[track_id].append((image_id, track_id, x_min, y_min, width, height))
                
                with open(currDirectory + output_file, 'a+') as file:
                    file.write(f"{image_id},{track_id},{x_min},{y_min},{width},{height},{1},{-1},{-1},{-1} \n")

        #else:
             #print("Ids are not available.")

# %%
import subprocess

# Exécuter une commande shell
subprocess.run(["python3", "TrackEval/scripts/run_mot_challenge.py", "--USE_PARALLEL", "False", "--METRICS", "HOTA", "--TRACKERS_TO_EVAL", "ByteTrack"])
# Out:
# Error importing BURST due to missing underlying dependency: No module named 'pycocotools'
#
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : /home/ariste/Documents/Maitrise-Genie-Info/Vision-par-ordinateur/Chapitre4/TP3/TrackEval/error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : False
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# MotChallenge2DBox Config:
# PRINT_CONFIG         : True
# GT_FOLDER            : /home/ariste/Documents/Maitrise-Genie-Info/Vision-par-ordinateur/Chapitre4/TP3/TrackEval/data/gt/mot_challenge/
# TRACKERS_FOLDER      : /home/ariste/Documents/Maitrise-Genie-Info/Vision-par-ordinateur/Chapitre4/TP3/TrackEval/data/trackers/mot_challenge/
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['ByteTrack']
# CLASSES_TO_EVAL      : ['pedestrian']
# BENCHMARK            : MOT17
# SPLIT_TO_EVAL        : train
# INPUT_AS_ZIP         : False
# DO_PREPROC           : True
# TRACKER_SUB_FOLDER   : data
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# SEQMAP_FILE          : None
# SEQ_INFO             : None
# GT_LOC_FORMAT        : {gt_folder}/{seq}/gt/gt.txt
# SKIP_SPLIT_FOL       : False
#
# Evaluating 1 tracker(s) on 21 sequence(s) for 1 class(es) on MotChallenge2DBox dataset using the following metrics: HOTA, Count
#
#
# Evaluating ByteTrack
#
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-02-DPM)            0.5315 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2012 sec
#     HOTA.eval_sequence()                                                   0.2657 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 1 eval_sequence(MOT17-02-DPM, ByteTrack)                                 1.0003 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-02-FRCNN)          0.4364 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2541 sec
#     HOTA.eval_sequence()                                                   0.2514 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 2 eval_sequence(MOT17-02-FRCNN, ByteTrack)                               0.9439 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-02-SDP)            0.4892 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2278 sec
#     HOTA.eval_sequence()                                                   0.2160 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 3 eval_sequence(MOT17-02-SDP, ByteTrack)                                 0.9349 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-04-DPM)            1.4011 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.4121 sec
#     HOTA.eval_sequence()                                                   0.4595 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 4 eval_sequence(MOT17-04-DPM, ByteTrack)                                 2.2775 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-04-FRCNN)          1.4409 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.3896 sec
#     HOTA.eval_sequence()                                                   0.4387 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 5 eval_sequence(MOT17-04-FRCNN, ByteTrack)                               2.2731 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-04-SDP)            0.9629 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.3925 sec
#     HOTA.eval_sequence()                                                   0.4185 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 6 eval_sequence(MOT17-04-SDP, ByteTrack)                                 1.7779 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-05-DPM)            0.3420 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2488 sec
#     HOTA.eval_sequence()                                                   0.3382 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 7 eval_sequence(MOT17-05-DPM, ByteTrack)                                 0.9318 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-05-FRCNN)          0.3551 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2700 sec
#     HOTA.eval_sequence()                                                   0.3942 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 8 eval_sequence(MOT17-05-FRCNN, ByteTrack)                               1.0229 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-05-SDP)            0.3113 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.3038 sec
#     HOTA.eval_sequence()                                                   0.3556 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 9 eval_sequence(MOT17-05-SDP, ByteTrack)                                 0.9741 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-09-DPM)            0.2742 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.1856 sec
#     HOTA.eval_sequence()                                                   0.2245 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 10 eval_sequence(MOT17-09-DPM, ByteTrack)                                 0.6861 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-09-FRCNN)          0.2743 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.1490 sec
#     HOTA.eval_sequence()                                                   0.1848 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 11 eval_sequence(MOT17-09-FRCNN, ByteTrack)                               0.6101 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-09-SDP)            0.2756 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.1588 sec
#     HOTA.eval_sequence()                                                   0.1885 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 12 eval_sequence(MOT17-09-SDP, ByteTrack)                                 0.6248 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-10-DPM)            0.1593 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.0992 sec
#     HOTA.eval_sequence()                                                   0.0352 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 13 eval_sequence(MOT17-10-DPM, ByteTrack)                                 0.2956 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-10-FRCNN)          0.4054 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2735 sec
#     HOTA.eval_sequence()                                                   0.3165 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 14 eval_sequence(MOT17-10-FRCNN, ByteTrack)                               1.0002 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-10-SDP)            0.2161 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2241 sec
#     HOTA.eval_sequence()                                                   0.2429 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 15 eval_sequence(MOT17-10-SDP, ByteTrack)                                 0.6852 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-11-DPM)            0.3996 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.3199 sec
#     HOTA.eval_sequence()                                                   0.3793 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 16 eval_sequence(MOT17-11-DPM, ByteTrack)                                 1.1019 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-11-FRCNN)          0.2496 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2824 sec
#     HOTA.eval_sequence()                                                   0.3947 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 17 eval_sequence(MOT17-11-FRCNN, ByteTrack)                               0.9325 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-11-SDP)            0.2344 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.3110 sec
#     HOTA.eval_sequence()                                                   0.3707 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 18 eval_sequence(MOT17-11-SDP, ByteTrack)                                 0.9194 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-13-DPM)            0.5066 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2325 sec
#     HOTA.eval_sequence()                                                   0.2261 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 19 eval_sequence(MOT17-13-DPM, ByteTrack)                                 0.9680 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-13-FRCNN)          0.2293 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2264 sec
#     HOTA.eval_sequence()                                                   0.2494 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 20 eval_sequence(MOT17-13-FRCNN, ByteTrack)                               0.7075 sec
#     MotChallenge2DBox.get_raw_seq_data(ByteTrack, MOT17-13-SDP)            0.3691 sec
#     MotChallenge2DBox.get_preprocessed_seq_data(pedestrian)                0.2233 sec
#     HOTA.eval_sequence()                                                   0.2435 sec
#     Count.eval_sequence()                                                  0.0000 sec
# 21 eval_sequence(MOT17-13-SDP, ByteTrack)                                 0.8393 sec
#
# All sequences for ByteTrack finished in 21.51 seconds
#
# HOTA: ByteTrack-pedestrian         HOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# MOT17-02-DPM                       25.029    14.91     42.041    15.136    82.065    43.8      83.743    84.364    25.223    30.466    80.969    24.668
# MOT17-02-FRCNN                     25.029    14.91     42.041    15.136    82.065    43.8      83.743    84.364    25.223    30.466    80.969    24.668
# MOT17-02-SDP                       25.029    14.91     42.041    15.136    82.065    43.8      83.743    84.364    25.223    30.466    80.969    24.668
# MOT17-04-DPM                       37.17     25.49     54.366    26.223    82.181    56.812    87.116    84.751    37.733    45.686    80.567    36.808
# MOT17-04-FRCNN                     37.17     25.49     54.366    26.223    82.181    56.812    87.116    84.751    37.733    45.686    80.567    36.808
# MOT17-04-SDP                       37.17     25.49     54.366    26.223    82.181    56.812    87.116    84.751    37.733    45.686    80.567    36.808
# MOT17-05-DPM                       41.39     40.1      42.911    43.333    71.331    50.234    65.987    78.941    43.105    58.744    71.554    42.034
# MOT17-05-FRCNN                     41.39     40.1      42.911    43.333    71.331    50.234    65.987    78.941    43.105    58.744    71.554    42.034
# MOT17-05-SDP                       41.39     40.1      42.911    43.333    71.331    50.234    65.987    78.941    43.105    58.744    71.554    42.034
# MOT17-09-DPM                       42.879    48.674    37.924    51.577    79.424    46.541    67.771    82.929    44.215    54.878    78.095    42.857
# MOT17-09-FRCNN                     42.879    48.674    37.924    51.577    79.424    46.541    67.771    82.929    44.215    54.878    78.095    42.857
# MOT17-09-SDP                       42.879    48.674    37.924    51.577    79.424    46.541    67.771    82.929    44.215    54.878    78.095    42.857
# MOT17-10-DPM                       1.7091    0.33843   8.6601    0.33861   73.684    8.7452    78.443    79.628    1.7095    2.2116    72.736    1.6086
# MOT17-10-FRCNN                     30.868    25.707    37.146    26.57     76.178    39.582    77.242    80.456    31.407    40.507    75.445    30.56
# MOT17-10-SDP                       30.868    25.707    37.146    26.57     76.178    39.582    77.242    80.456    31.407    40.507    75.445    30.56
# MOT17-11-DPM                       47.5      47.916    47.293    50.785    81.915    50.272    82.177    85.392    48.986    58.316    81.14     47.318
# MOT17-11-FRCNN                     47.5      47.916    47.293    50.785    81.915    50.272    82.177    85.392    48.986    58.316    81.14     47.318
# MOT17-11-SDP                       47.5      47.916    47.293    50.785    81.915    50.272    82.177    85.392    48.986    58.316    81.14     47.318
# MOT17-13-DPM                       24.519    14.988    40.499    15.307    76.415    43.126    76.687    80.881    24.813    31.126    75.776    23.586
# MOT17-13-FRCNN                     24.519    14.988    40.499    15.307    76.415    43.126    76.687    80.881    24.813    31.126    75.776    23.586
# MOT17-13-SDP                       24.519    14.988    40.499    15.307    76.415    43.126    76.687    80.881    24.813    31.126    75.776    23.586
# COMBINED                           34.918    25.749    47.593    26.617    79.815    51.188    81.342    83.474    35.548    43.657    78.757    34.383
#
# Count: ByteTrack-pedestrian        Dets      GT_Dets   IDs       GT_IDs
# MOT17-02-DPM                       3427      18581     35        62
# MOT17-02-FRCNN                     3427      18581     35        62
# MOT17-02-SDP                       3427      18581     35        62
# MOT17-04-DPM                       15175     47557     66        83
# MOT17-04-FRCNN                     15175     47557     66        83
# MOT17-04-SDP                       15175     47557     66        83
# MOT17-05-DPM                       4202      6917      116       133
# MOT17-05-FRCNN                     4202      6917      116       133
# MOT17-05-SDP                       4202      6917      116       133
# MOT17-09-DPM                       3458      5325      37        26
# MOT17-09-FRCNN                     3458      5325      37        26
# MOT17-09-SDP                       3458      5325      37        26
# MOT17-10-DPM                       59        12839     7         57
# MOT17-10-FRCNN                     4478      12839     53        57
# MOT17-10-SDP                       4478      12839     53        57
# MOT17-11-DPM                       5850      9436      57        75
# MOT17-11-FRCNN                     5850      9436      57        75
# MOT17-11-SDP                       5850      9436      57        75
# MOT17-13-DPM                       2332      11642     50        110
# MOT17-13-FRCNN                     2332      11642     50        110
# MOT17-13-SDP                       2332      11642     50        110
# COMBINED                           112347    336891    1196      1638
#
# Timing analysis:
# MotChallenge2DBox.get_raw_seq_data                                     9.8640 sec
# MotChallenge2DBox.get_preprocessed_seq_data                            5.3858 sec
# HOTA.eval_sequence                                                     6.1941 sec
# Count.eval_sequence                                                    0.0000 sec
# eval_sequence                                                          21.5071 sec
# Evaluator.evaluate                                                     25.4525 sec
# CompletedProcess(args=['python3', 'TrackEval/scripts/run_mot_challenge.py', '--USE_PARALLEL', 'False', '--METRICS', 'HOTA', '--TRACKERS_TO_EVAL', 'ByteTrack'], returncode=0)
